# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
mlb_df = pd.read_csv("Resources/mlb_complete_8years.csv")
mlb_df.drop(columns=['Unnamed: 0','W','L','W-L%'], inplace=True)
mlb_df.head(30)
# Out:
#                             Tm  BatAge   R/G    AB  R_x   H_x   2B  3B  HR_x  \
# 0    Arizona Diamondbacks_2022    26.5  4.33  5351  702  1232  262  24   173
# 1          Atlanta Braves_2022    27.5  4.87  5509  789  1394  298  11   243
# 2       Baltimore Orioles_2022    27.0  4.16  5429  674  1281  275  25   171
# 3          Boston Red Sox_2022    28.8  4.54  5539  735  1427  352  12   155
# 4            Chicago Cubs_2022    27.9  4.06  5425  657  1293  265  31   159
# 5       Chicago White Sox_2022    29.3  4.23  5611  686  1435  272   9   149
# 6         Cincinnati Reds_2022    29.4  4.00  5380  648  1264  235  18   156
# 7     Cleveland Guardians_2022    25.9  4.31  5558  698  1410  273  31   127
# 8        Colorado Rockies_2022    29.1  4.31  5540  698  1408  280  34   149
# 9          Detroit Tigers_2022    27.9  3.44  5378  557  1240  235  27   110
# 10         Houston Astros_2022    29.3  4.55  5409  737  1341  284  13   214
# 11     Kansas City Royals_2022    27.1  3.95  5437  640  1327  247  38   138
# 12     Los Angeles Angels_2022    27.9  3.85  5423  623  1265  219  31   190
# 13    Los Angeles Dodgers_2022    29.6  5.23  5526  847  1418  325  31   212
# 14          Miami Marlins_2022    28.9  3.62  5395  586  1241  248  20   144
# 15      Milwaukee Brewers_2022    29.1  4.48  5417  725  1271  251  17   219
# 16        Minnesota Twins_2022    26.9  4.30  5476  696  1356  269  18   178
# 17          New York Mets_2022    29.7  4.77  5489  772  1422  272  27   171
# 18       New York Yankees_2022    30.2  4.98  5422  807  1308  225   8   254
# 19      Oakland Athletics_2022    28.3  3.51  5314  568  1147  249  15   137
# 20  Philadelphia Phillies_2022    28.1  4.61  5496  747  1392  255  29   205
# 21     Pittsburgh Pirates_2022    26.3  3.65  5331  591  1186  221  29   158
# 22       San Diego Padres_2022    28.2  4.35  5468  705  1317  275  18   153
# 23       Seattle Mariners_2022    27.5  4.26  5375  690  1236  229  19   197
# 24   San Francisco Giants_2022    30.0  4.42  5392  716  1261  255  18   183
# 25    St. Louis Cardinals_2022    28.8  4.77  5496  772  1386  290  21   197
# 26         Tampa Bay Rays_2022    27.0  4.11  5412  666  1294  296  17   139
# 27          Texas Rangers_2022    28.0  4.36  5478  707  1308  224  20   198
# 28      Toronto Blue Jays_2022    27.1  4.78  5555  775  1464  307  12   200
# 29   Washington Nationals_2022    28.7  3.72  5434  603  1351  252  20   136
#
#     RBI  ...    BF  LOB_y  DefEff    Ch    PO     A    E   DP  post_season  \
# 0   658  ...  6065   1051   0.704  5746  4290  1370   86  134        False
# 1   753  ...  6031   1101   0.701  5803  4344  1382   77  110         True
# 2   639  ...  6058   1092   0.690  5920  4300  1529   91  151        False
# 3   704  ...  6167   1109   0.683  5825  4293  1447   85  134        False
# 4   620  ...  6162   1130   0.697  5880  4331  1453   96  139        False
# 5   654  ...  6145   1110   0.688  5738  4343  1293  102  122        False
# 6   618  ...  6220   1152   0.689  5647  4270  1296   81  115        False
# 7   662  ...  5989   1018   0.709  5908  4368  1443   97  127         True
# 8   669  ...  6240   1110   0.673  5968  4276  1592  100  154        False
# 9   530  ...  6047   1086   0.701  5757  4259  1404   94  137        False
# 10  715  ...  5856   1017   0.719  5698  4336  1290   72  122         True
# 11  613  ...  6249   1204   0.675  5829  4248  1499   82  153        False
# 12  600  ...  6038   1085   0.709  5773  4307  1382   84  134        False
# 13  812  ...  5865   1015   0.729  5788  4354  1351   83  120         True
# 14  554  ...  6056   1088   0.694  5841  4312  1460   69  143        False
# 15  703  ...  6057   1057   0.704  5848  4338  1419   91  122        False
# 16  668  ...  6042   1071   0.702  5701  4311  1307   83  121        False
# 17  735  ...  5950   1041   0.692  5742  4316  1359   67  128         True
# 18  764  ...  5938   1047   0.720  5902  4355  1473   74  102         True
# 19  537  ...  6121   1087   0.697  5837  4279  1466   92  139        False
# 20  719  ...  6006   1052   0.687  5770  4285  1416   69  129         True
# 21  555  ...  6263   1197   0.677  5891  4263  1507  121  152        False
# 22  682  ...  6047   1076   0.705  5768  4330  1362   76  116         True
# 23  663  ...  5986   1047   0.710  5727  4341  1317   69  114         True
# 24  683  ...  6070   1090   0.674  5945  4299  1546  100  130        False
# 25  739  ...  6014   1088   0.702  6074  4307  1701   66  181         True
# 26  634  ...  5930   1038   0.708  5777  4307  1386   84  110         True
# 27  670  ...  6167   1140   0.693  5929  4305  1528   96  143        False
# 28  756  ...  6053   1069   0.691  5754  4324  1348   82  120         True
# 29  579  ...  6220   1143   0.687  5749  4235  1410  104  126        False
#
#     Year
# 0   2022
# 1   2022
# 2   2022
# 3   2022
# 4   2022
# 5   2022
# 6   2022
# 7   2022
# 8   2022
# 9   2022
# 10  2022
# 11  2022
# 12  2022
# 13  2022
# 14  2022
# 15  2022
# 16  2022
# 17  2022
# 18  2022
# 19  2022
# 20  2022
# 21  2022
# 22  2022
# 23  2022
# 24  2022
# 25  2022
# 26  2022
# 27  2022
# 28  2022
# 29  2022
#
# [30 rows x 39 columns]

# %%
features_df = mlb_df.drop(columns=['Tm','post_season','Year'])
target_df = mlb_df['post_season'].astype(int)

# %%
target_df
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 235    1
# 236    0
# 237    1
# 238    1
# 239    0
# Name: post_season, Length: 240, dtype: int32

# %%
features_df.shape
# Out:
# (240, 36)

# %%
features_df
# Out:
#      BatAge   R/G    AB  R_x   H_x   2B  3B  HR_x  RBI   SB  ...  SO_y  HBP_y  \
# 0      26.5  4.33  5351  702  1232  262  24   173  658  104  ...  1216     59
# 1      27.5  4.87  5509  789  1394  298  11   243  753   87  ...  1554     62
# 2      27.0  4.16  5429  674  1281  275  25   171  639   95  ...  1214     64
# 3      28.8  4.54  5539  735  1427  352  12   155  704   52  ...  1346     72
# 4      27.9  4.06  5425  657  1293  265  31   159  620  111  ...  1383     73
# ..      ...   ...   ...  ...   ...  ...  ..   ...  ...  ...  ...   ...    ...
# 235    28.4  3.99  5484  647  1386  288  39   137  619   69  ...  1329     45
# 236    28.5  3.98  5485  644  1383  278  32   167  612   87  ...  1355     46
# 237    28.7  4.64  5511  751  1419  279  32   172  707  101  ...  1095     63
# 238    29.5  5.50  5509  891  1480  308  17   232  852   88  ...  1117     59
# 239    28.4  4.34  5428  703  1363  265  13   177  665   57  ...  1342     55
#
#        BF  LOB_y  DefEff    Ch    PO     A    E   DP
# 0    6065   1051   0.704  5746  4290  1370   86  134
# 1    6031   1101   0.701  5803  4344  1382   77  110
# 2    6058   1092   0.690  5920  4300  1529   91  151
# 3    6167   1109   0.683  5825  4293  1447   85  134
# 4    6162   1130   0.697  5880  4331  1453   96  139
# ..    ...    ...     ...   ...   ...   ...  ...  ...
# 235  6134   1215   0.688  6107  4394  1617   96  159
# 236  6069   1067   0.701  5863  4360  1408   95  118
# 237  6215   1154   0.687  6142  4328  1695  119  169
# 238  5984    991   0.708  6003  4323  1592   88  145
# 239  5975   1036   0.685  5927  4304  1533   90  125
#
# [240 rows x 36 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features_df, target_df, random_state=78)
X_scaler = skl.preprocessing.StandardScaler()
X_scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=36))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)
# Out:
# INFO:tensorflow:Reloading Tuner from .\untitled_project\tuner0.json

# %%
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 3,
#  'num_layers': 2,
#  'units_0': 9,
#  'units_1': 7,
#  'units_2': 5,
#  'units_3': 7,
#  'units_4': 1,
#  'units_5': 3,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 0,
#  'tuner/round': 0}

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2/2 - 1s - loss: 0.4233 - accuracy: 0.8833 - 539ms/epoch - 270ms/step
# Loss: 0.42331045866012573, Accuracy: 0.8833333253860474

# %%
best_model

# %%
from keras.models import load_model
best_model.save('mlb_network.h5')
mlb_model = load_model("mlb_network.h5")
loss, accuracy = mlb_model.evaluate(X_test, y_test)
# Out:
# C:\Users\nelso\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 1s 16ms/step - loss: 1549.9866 - accuracy: 0.7667

# %%
bat_23 = pd.read_csv("Resources/2023_Batting.csv")
bat_23.drop(columns=['#Bat','G','PA','BA','OBP','SLG', 'OPS', 'OPS+','TB', 'GDP','IBB'], inplace=True)
pit_23 = pd.read_csv("Resources/2023_Pitching.csv")
pit_23.drop(columns=['#P', 'ERA', 'G', 'GS', 'GF','CG', 'cSho', 'IP', 'ER', 'BK', 'WP','ERA+', 'FIP', 'WHIP', 'H9', 'HR9','BB9', 'SO9', 'SO/W'], inplace=True)
def_23 = pd.read_csv("Resources/2023_Fielding.csv")
def_23.drop(columns=['#Fld', 'RA/G', 'G', 'GS', 'CG', 'Inn', 'Fld%', 'Rtot', 'Rtot/yr', 'Rdrs', 'Rdrs/yr', 'Rgood'], inplace=True)
merged_23 = pd.merge(bat_23, pit_23, on='Tm')
merged_23 = pd.merge(merged_23, def_23, on = 'Tm')
merged_23.head(30)
# Out:
#                        Tm  BatAge   R/G    AB  R_x  H_x   2B  3B  HR_x  RBI  \
# 0    Arizona Diamondbacks    27.4  5.02  1864  276  487  107  12    64  262
# 1          Atlanta Braves    27.9  5.05  1861  278  478   98   4    91  269
# 2       Baltimore Orioles    27.2  4.96  1850  273  464  100  10    64  265
# 3          Boston Red Sox    28.6  5.20  1851  281  489  120   4    61  271
# 4            Chicago Cubs    28.7  4.54  1837  245  468   82   7    66  237
# 5       Chicago White Sox    27.9  4.32  1939  246  466  101   7    59  241
# 6         Cincinnati Reds    27.5  4.65  1822  251  469  101  10    42  242
# 7     Cleveland Guardians    27.0  3.48  1788  188  409   92  10    30  172
# 8        Colorado Rockies    29.4  4.57  1895  256  498  127   7    47  246
# 9          Detroit Tigers    27.3  3.79  1801  201  412   85   3    46  195
# 10         Houston Astros    28.6  4.52  1804  244  441   89   4    56  233
# 11     Kansas City Royals    26.8  3.95  1881  221  437   94  13    56  211
# 12     Los Angeles Angels    28.9  4.79  1899  268  486   84   6    73  264
# 13    Los Angeles Dodgers    30.8  5.59  1878  313  452  106  11    93  302
# 14          Miami Marlins    29.8  3.76  1865  207  483   80   9    54  196
# 15      Milwaukee Brewers    27.6  4.00  1756  216  405   66   3    64  206
# 16        Minnesota Twins    28.7  4.51  1859  248  431   84   7    74  235
# 17          New York Mets    29.8  4.45  1829  245  451   74   9    63  236
# 18       New York Yankees    28.9  4.79  1893  273  458   74   8    87  265
# 19      Oakland Athletics    27.9  3.47  1887  198  416   73   6    57  191
# 20  Philadelphia Phillies    28.6  4.20  1839  227  467  103  11    55  218
# 21     Pittsburgh Pirates    28.3  4.30  1786  232  433  101  13    53  220
# 22       San Diego Padres    29.3  4.13  1763  223  392   88   4    63  211
# 23       Seattle Mariners    27.8  4.51  1843  248  423   95   4    61  239
# 24   San Francisco Giants    28.9  4.60  1878  253  464   89   3    76  250
# 25    St. Louis Cardinals    27.9  4.79  1949  273  493  100   5    76  263
# 26         Tampa Bay Rays    26.9  5.89  1926  336  518  102   9   101  323
# 27          Texas Rangers    28.3  6.37  1880  344  511  109   7    71  330
# 28      Toronto Blue Jays    28.9  4.80  1925  264  513   99   6    62  248
# 29   Washington Nationals    26.9  4.18  1878  230  494   91   9    39  220
#
#     ...  SO_y  HBP_y    BF  LOB_y  DefEff    Ch    PO    A   E  DP
# 0   ...   463     13  2083    363   0.697  1985  1465  501  19  38
# 1   ...   524     25  2064    385   0.673  1951  1461  454  36  48
# 2   ...   496     17  2099    377   0.683  1992  1490  478  24  61
# 3   ...   450     26  2047    356   0.691  1922  1422  466  34  37
# 4   ...   453     20  2006    339   0.690  1956  1434  497  25  55
# 5   ...   529     33  2208    415   0.691  1959  1507  424  28  39
# 6   ...   489     25  2099    403   0.661  1877  1426  429  22  42
# 7   ...   409     17  2035    370   0.701  1986  1451  507  28  37
# 8   ...   405     19  2145    376   0.678  2034  1458  545  31  58
# 9   ...   419     16  2003    334   0.705  1919  1422  468  29  37
# 10  ...   528     20  1981    354   0.693  1908  1442  445  21  46
# 11  ...   475     22  2142    385   0.680  1962  1468  469  25  44
# 12  ...   486     33  2130    385   0.690  2006  1487  484  35  49
# 13  ...   461     22  2083    354   0.699  1984  1481  479  24  41
# 14  ...   502     22  2109    397   0.679  1988  1468  488  32  51
# 15  ...   429     25  2034    370   0.706  1916  1425  467  24  38
# 16  ...   543     13  2049    369   0.697  1931  1485  412  34  37
# 17  ...   454     30  2050    369   0.706  1918  1428  472  18  45
# 18  ...   518     32  2155    398   0.708  2056  1532  490  34  45
# 19  ...   431     39  2302    420   0.680  1975  1500  440  35  44
# 20  ...   489     20  2028    353   0.676  1877  1411  438  28  28
# 21  ...   468     12  2046    389   0.685  1893  1429  428  36  44
# 22  ...   451     22  2019    365   0.708  1926  1437  470  19  42
# 23  ...   497     15  2047    349   0.695  1980  1484  475  21  34
# 24  ...   485     23  2062    363   0.680  2044  1460  545  39  55
# 25  ...   487     23  2206    434   0.664  2071  1511  537  23  53
# 26  ...   476     23  2111    381   0.716  2076  1515  541  20  48
# 27  ...   445     20  1971    327   0.707  1931  1435  472  24  49
# 28  ...   511     24  2074    381   0.698  1937  1463  446  28  42
# 29  ...   406     16  2100    393   0.690  2012  1445  531  36  52
#
# [30 rows x 40 columns]

# %%
merged_23.to_csv('Resources/season2023.csv')

# %%
season_2023 = pd.read_csv('Resources/season2023.csv')
season_2023.drop(columns=['Unnamed: 0','W','L','W-L%'], inplace=True)
season_2023.set_index('Tm', inplace=True)

# %%
season_2023.head(30)
# Out:
#                        BatAge   R/G    AB  R_x  H_x   2B  3B  HR_x  RBI  SB  \
# Tm
# Arizona Diamondbacks     27.4  5.02  1864  276  487  107  12    64  262  51
# Atlanta Braves           27.9  5.05  1861  278  478   98   4    91  269  36
# Baltimore Orioles        27.2  4.96  1850  273  464  100  10    64  265  45
# Boston Red Sox           28.6  5.20  1851  281  489  120   4    61  271  31
# Chicago Cubs             28.7  4.54  1837  245  468   82   7    66  237  41
# Chicago White Sox        27.9  4.32  1939  246  466  101   7    59  241  31
# Cincinnati Reds          27.5  4.65  1822  251  469  101  10    42  242  43
# Cleveland Guardians      27.0  3.48  1788  188  409   92  10    30  172  46
# Colorado Rockies         29.4  4.57  1895  256  498  127   7    47  246  19
# Detroit Tigers           27.3  3.79  1801  201  412   85   3    46  195  33
# Houston Astros           28.6  4.52  1804  244  441   89   4    56  233  29
# Kansas City Royals       26.8  3.95  1881  221  437   94  13    56  211  40
# Los Angeles Angels       28.9  4.79  1899  268  486   84   6    73  264  26
# Los Angeles Dodgers      30.8  5.59  1878  313  452  106  11    93  302  30
# Miami Marlins            29.8  3.76  1865  207  483   80   9    54  196  44
# Milwaukee Brewers        27.6  4.00  1756  216  405   66   3    64  206  42
# Minnesota Twins          28.7  4.51  1859  248  431   84   7    74  235  23
# New York Mets            29.8  4.45  1829  245  451   74   9    63  236  38
# New York Yankees         28.9  4.79  1893  273  458   74   8    87  265  41
# Oakland Athletics        27.9  3.47  1887  198  416   73   6    57  191  53
# Philadelphia Phillies    28.6  4.20  1839  227  467  103  11    55  218  35
# Pittsburgh Pirates       28.3  4.30  1786  232  433  101  13    53  220  58
# San Diego Padres         29.3  4.13  1763  223  392   88   4    63  211  42
# Seattle Mariners         27.8  4.51  1843  248  423   95   4    61  239  33
# San Francisco Giants     28.9  4.60  1878  253  464   89   3    76  250  32
# St. Louis Cardinals      27.9  4.79  1949  273  493  100   5    76  263  44
# Tampa Bay Rays           26.9  5.89  1926  336  518  102   9   101  323  75
# Texas Rangers            28.3  6.37  1880  344  511  109   7    71  330  33
# Toronto Blue Jays        28.9  4.80  1925  264  513   99   6    62  248  42
# Washington Nationals     26.9  4.18  1878  230  494   91   9    39  220  27
#
#                        ...  SO_y  HBP_y    BF  LOB_y  DefEff    Ch    PO    A  \
# Tm                     ...
# Arizona Diamondbacks   ...   463     13  2083    363   0.697  1985  1465  501
# Atlanta Braves         ...   524     25  2064    385   0.673  1951  1461  454
# Baltimore Orioles      ...   496     17  2099    377   0.683  1992  1490  478
# Boston Red Sox         ...   450     26  2047    356   0.691  1922  1422  466
# Chicago Cubs           ...   453     20  2006    339   0.690  1956  1434  497
# Chicago White Sox      ...   529     33  2208    415   0.691  1959  1507  424
# Cincinnati Reds        ...   489     25  2099    403   0.661  1877  1426  429
# Cleveland Guardians    ...   409     17  2035    370   0.701  1986  1451  507
# Colorado Rockies       ...   405     19  2145    376   0.678  2034  1458  545
# Detroit Tigers         ...   419     16  2003    334   0.705  1919  1422  468
# Houston Astros         ...   528     20  1981    354   0.693  1908  1442  445
# Kansas City Royals     ...   475     22  2142    385   0.680  1962  1468  469
# Los Angeles Angels     ...   486     33  2130    385   0.690  2006  1487  484
# Los Angeles Dodgers    ...   461     22  2083    354   0.699  1984  1481  479
# Miami Marlins          ...   502     22  2109    397   0.679  1988  1468  488
# Milwaukee Brewers      ...   429     25  2034    370   0.706  1916  1425  467
# Minnesota Twins        ...   543     13  2049    369   0.697  1931  1485  412
# New York Mets          ...   454     30  2050    369   0.706  1918  1428  472
# New York Yankees       ...   518     32  2155    398   0.708  2056  1532  490
# Oakland Athletics      ...   431     39  2302    420   0.680  1975  1500  440
# Philadelphia Phillies  ...   489     20  2028    353   0.676  1877  1411  438
# Pittsburgh Pirates     ...   468     12  2046    389   0.685  1893  1429  428
# San Diego Padres       ...   451     22  2019    365   0.708  1926  1437  470
# Seattle Mariners       ...   497     15  2047    349   0.695  1980  1484  475
# San Francisco Giants   ...   485     23  2062    363   0.680  2044  1460  545
# St. Louis Cardinals    ...   487     23  2206    434   0.664  2071  1511  537
# Tampa Bay Rays         ...   476     23  2111    381   0.716  2076  1515  541
# Texas Rangers          ...   445     20  1971    327   0.707  1931  1435  472
# Toronto Blue Jays      ...   511     24  2074    381   0.698  1937  1463  446
# Washington Nationals   ...   406     16  2100    393   0.690  2012  1445  531
#
#                         E  DP
# Tm
# Arizona Diamondbacks   19  38
# Atlanta Braves         36  48
# Baltimore Orioles      24  61
# Boston Red Sox         34  37
# Chicago Cubs           25  55
# Chicago White Sox      28  39
# Cincinnati Reds        22  42
# Cleveland Guardians    28  37
# Colorado Rockies       31  58
# Detroit Tigers         29  37
# Houston Astros         21  46
# Kansas City Royals     25  44
# Los Angeles Angels     35  49
# Los Angeles Dodgers    24  41
# Miami Marlins          32  51
# Milwaukee Brewers      24  38
# Minnesota Twins        34  37
# New York Mets          18  45
# New York Yankees       34  45
# Oakland Athletics      35  44
# Philadelphia Phillies  28  28
# Pittsburgh Pirates     36  44
# San Diego Padres       19  42
# Seattle Mariners       21  34
# San Francisco Giants   39  55
# St. Louis Cardinals    23  53
# Tampa Bay Rays         20  48
# Texas Rangers          24  49
# Toronto Blue Jays      28  42
# Washington Nationals   36  52
#
# [30 rows x 36 columns]

# %%
season_2023.shape
# Out:
# (30, 36)

# %%
scaled_2023 = X_scaler.transform(season_2023)

# %%
predictions = best_model.predict(scaled_2023)
# Out:
# 1/1 [==============================] - 0s 186ms/step

# %%
predictions
# Out:
# array([[0.51943964],
#        [0.48676503],
#        [0.525259  ],
#        [0.30435336],
#        [0.5282531 ],
#        [0.32827717],
#        [0.3560971 ],
#        [0.42987794],
#        [0.3402744 ],
#        [0.34697756],
#        [0.5282531 ],
#        [0.29210687],
#        [0.46718132],
#        [0.5282531 ],
#        [0.4258569 ],
#        [0.45116153],
#        [0.5282531 ],
#        [0.4038091 ],
#        [0.5282531 ],
#        [0.07422271],
#        [0.29512104],
#        [0.5015542 ],
#        [0.4490483 ],
#        [0.5282531 ],
#        [0.39988825],
#        [0.41407958],
#        [0.5081903 ],
#        [0.5282531 ],
#        [0.51112866],
#        [0.31901646]], dtype=float32)

# %%
season_2023['predictions'] = predictions
season_2023_predict = season_2023.copy()

# %%
season_2023_predict = season_2023_predict[['predictions']]

# %%
season_2023_predict.sort_values(by=['predictions'], ascending=False,inplace=True)
season_2023_predict.head(30)
# Out:
#                        predictions
# Tm
# Chicago Cubs              0.528253
# Texas Rangers             0.528253
# Seattle Mariners          0.528253
# New York Yankees          0.528253
# Houston Astros            0.528253
# Minnesota Twins           0.528253
# Los Angeles Dodgers       0.528253
# Baltimore Orioles         0.525259
# Arizona Diamondbacks      0.519440
# Toronto Blue Jays         0.511129
# Tampa Bay Rays            0.508190
# Pittsburgh Pirates        0.501554
# Atlanta Braves            0.486765
# Los Angeles Angels        0.467181
# Milwaukee Brewers         0.451162
# San Diego Padres          0.449048
# Cleveland Guardians       0.429878
# Miami Marlins             0.425857
# St. Louis Cardinals       0.414080
# New York Mets             0.403809
# San Francisco Giants      0.399888
# Cincinnati Reds           0.356097
# Detroit Tigers            0.346978
# Colorado Rockies          0.340274
# Chicago White Sox         0.328277
# Washington Nationals      0.319016
# Boston Red Sox            0.304353
# Philadelphia Phillies     0.295121
# Kansas City Royals        0.292107
# Oakland Athletics         0.074223
